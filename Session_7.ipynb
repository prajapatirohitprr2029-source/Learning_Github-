# %% [markdown]
# **try-except**
#
# - Try except is used to handle the exception mechanism
#
# - Try except is used to catch and handle the errors
#
# - When we get the error python will stop the excecution
#
# - Using try except eventhough we get the errors, the execution will not stop
#
# - It will cathch all the logical error automatically
#
# - The actual code Block will write in **try block**
#
# - If any error occurs in try block, will catch the errors in **except** Block
#
# - Synatax Error will not catch

# %% [markdown]
# catch all the error
# code execution will not stop
# original code is in = try
# error handling === except block

# %% [markdown]
# **See All Types of Error :**

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %% [markdown]
# **Divide By Zero Error:**

# %%
100/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 100/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **Type Error:**

# %%
100 +'apple'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 100 +'apple'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Attribute Error:**

# %%
import math
math.rohit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import math
# ----> 2 math.rohit
#
# AttributeError: module 'math' has no attribute 'rohit'

# %% [markdown]
# **Module Not Found Error:**

# %%
import rohit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import rohit
#
# ModuleNotFoundError: No module named 'rohit'

# %% [markdown]
# **Name Error:**

# %%
1*rohit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 1*rohit
#
# NameError: name 'rohit' is not defined

# %% [markdown]
# - Value Error
#
# - Type Error
#
# - Name Error
#
# - Zero Division Error
#
# - Module Not Found
#
# - Attribue Error
#
# - File Exist Error
#
# - Run Time Error

# %%
try:
    <original code>
except Exception as e:
    print(e)

# %%
try:
    int('10.5')
except Exception as e:
    print (e)
# Out:
# invalid literal for int() with base 10: '10.5'

# %%
try:
    ans=int(10.5)
    print(ans)
except exception as e:
    print(e)
    print(100+200)

# %%
try:
    ans=int(10.5)
    print(ans)
except exception as e:
    print(e)
    print(100+200)
# Out:
# 10

# %%
try:
    print('hi')
    print('hello')
    int('10.5')
    print('good')
except Exception as e:
    print(e)
    print('you written wrong')
# Out:
# hi
# hello
# invalid literal for int() with base 10: '10.5'
# you written wrong

# %%
try:
    int('10.5')
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: '10.5'

# %%
try:
    100+'apple'
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    os.makedirs("rohit")
except Exception as e:
    print(e)
# Out:
# name 'os' is not defined

# %%
## wap ask the user salary
# ask the user tax %
# cal how much tax we need to pay
# use TAB make it in a row

try:
    salary = eval ( input ('Enter The Salary:'))
    tax_per= eval ( input ('Enter Tax Percentage:'))
    tax = salary*tax_per/100
    print(f'The total tax is {tax}' )
except Exception as e:
    print(e)
# Out:
# Enter The Salary: 500000
# Enter Tax Percentage: 5
# The total tax is 25000.0

# %%
try:
    salary = eval ( input ('Enter The Salary:'))
    tax_per= eval ( input ('Enter Tax Percentage:'))
    tax = salarytax_per/100
    print(f'The total tax is {tax}' )
except Exception as e:
    print(e)
# Out:
# Enter The Salary: 500000
# Enter Tax Percentage: 5
# name 'salarytax_per' is not defined

# %%
# even - odd code

try:
    num = eval ( input ( " Enter a Number " ) )
    if num%2==0:
        print(f'The {num} is an Even:')
    else:
        print(f' the {num} is an odd:')
except Exception is e:
    print(e)
# Out:
#  Enter a Number  96
# The 96 is an Even:

# %% [markdown]
# **try-except-finally**
#
# - Original code in **try** block
#
# - error catch in **except** bloack
#
# - **finally** Block will activate either or try and except activate
#
# - assume that try block excecuted then finally block can also excecute
#
# - assume that except block excecuted then also finally block excecuted
#
# coffee well === try clean the kitchen == finally
#
# coffee gone === except clean the kitchen == finally

# %%
try:
    print('connection established')
except Exception as e:
    print(e)
finally:
    print('connection closed')
# Out:
# connection established
# connection closed

# %%
try:
    num = eval ( print ('Enter a Number between 55 to 60:') )
    if num
