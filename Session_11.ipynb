# %% [markdown]
# - Representations
#
# - Inbuilt Function
#
#    - type
#
#    - print
#
#    - min
#
#    - max
#
#    - len
#
#    - sum
#
#    - sorted
#
#    - reversed
#
# - Concatenation
#
# - Index Operations
#
# - Mutable vs Immutable
#
# - Slice
#
# - Methods

# %% [markdown]
# **Representations**

# %%
s1="python"
s2="python"
s3="I like 'python'"
s4="I like python"

# %% [raw]
# type()
# print()
# len()
# min()
# max()
# sum()
# sorted()
# reversed()

# %%
type('Rohit')
# Out:
# str

# %%
print('Rohit')
# Out:
# Rohit

# %%
len('Rohit')
# Out:
# 5

# %%
min('Rohit')
# Out:
# 'R'

# %%
max('Rohit')
# Out:
# 't'

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sum("p+y+t+h+o+n")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sorted('python')

# here 'python' is iterable beacuse it can be print by loops
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %% [markdown]
# **Iterable**
#
# - Whenever we see iterable word recall loops
#
# - i can print something by using a loop
#
#     - that ccan be strings
#
#     - that can be list
#
#     - that can be tuple etc

# %%
sorted('python')
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %%
sorted('python',reverse=True )

# sorted(iterable, key=None, reverse=False)
# Out:
# ['y', 't', 'p', 'o', 'n', 'h']

# %%
sorted('python',reverse=True )

sorted(iterable, key=None, reverse=False)

sorted()

# %%
#reversed(sequence,/)
reversed('python')

# %%
list(reversed('python'))
# Out:
# ['n', 'o', 'h', 't', 'y', 'p']

# %%
ans=(reversed('python'))
for i in(ans):
    print(i)
# Out:
# n
# o
# h
# t
# y
# p

# %%
s1='python'
l1=['p','y','t','h','o','n']
l2=[10,20,2,3,50,60]
l3=['p','y','t',10,20,30]
len[l1]

# %% [markdown]
# **Concatenation**

# %%
s1='hai'
s2='hello'
s1+s2  # 'hai' + 'hello'
s1+ ' , ' +s2
# Out:
# 'hai , hello'

# %%
s1='hai'
s2='hello'
s1-s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 3
#       1 s1='hai'
#       2 s2='hello'
# ----> 3 s1-s2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s1='hai'
s2='hello'
s1/s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 s1='hai'
#       2 s2='hello'
# ----> 3 s1/s2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
s1='hai'
s2='hello'
s1*s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 s1='hai'
#       2 s2='hello'
# ----> 3 s1*s2
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s1-s2   #TypeError: unsupported operand type(s) for -: 'str' and 'str'
s1/s2   #unsupported operand type(s) for /: 'str' and 'str'
s1*s2   #can't multiply sequence by non-int of type 'str'

#can't multiply sequence by non-int of type 'str'
# can multiply sequence by int of type

# %% [markdown]
# **index**
#
# - index will give the idea how to access the elements in a string
#
# - function represents with normal parenthesis
#
# - access is represent with square brackets

# %%
s1='python'

# %%
-6  -5  -4  -3  -2  -1           
 p   y   t   h   o   n
 0   1   2   3   4   5

# %%
s1[0]
#[] - This bracket is used to access inside variable or anything 
#s1(0) # fail
# Out:
# 'p'

# %%
s1(0)
#s1(0) # fail
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 s1(0)
#
# TypeError: 'str' object is not callable

# %%
s1[0],s1[-6]
# Out:
# ('p', 'p')

# %%
s1[0]  # 'p' 
s1[1]  # 'y'
s1[2]  # 't'
s1[3]  # 'h'
s1[4]  # 'o'
s1[5]  # 'n'

#s1[i]  i=0 , 6

# %%
for i in range(0,6):
    print(i,s1[i])
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %%
s1='python'
for i in s1:
    print(i,end=' ')
# Out:
# p y t h o n

# %%
s1='python'
for i in range():
    print(s1[i],end=' ')


# i in ===== character
# i in range ===== number === char s1[i]
