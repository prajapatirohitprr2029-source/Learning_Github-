# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print(
# Out:
#   Cell In[1], line 4
#     print(
#           ^
# SyntaxError: incomplete input

# %%
print(')
# Out:
#   Cell In[2], line 1
#     print(')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print(f'the area of circle is : {area_of_circel}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 radius=100
#       3 area_of_circle=pi*radius*radius
# ----> 4 print(f'the area of circle is : {area_of_circel}')
#
# NameError: name 'area_of_circel' is not defined

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('the area of circle is : {}'.format(area_of_circle)
# Out:
#   Cell In[2], line 4
#     print('the area of circle is : {}'.format(area_of_circle)
#                                                              ^
# SyntaxError: incomplete input

# %%
pi=3.14
radius=100
area_of_circle=pi*radius*radius
print('the area of circle is :{}'.fotmat(area_of_circle))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 radius=100
#       3 area_of_circle=pi*radius*radius
# ----> 4 print('the area of circle is :{}'.fotmat(area_of_circle))
#
# AttributeError: 'str' object has no attribute 'fotmat'

# %%
print('the area of circle'=area_of_circle)
# Out:
#   Cell In[4], line 1
#     print('the area of circle'=area_of_circle)
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
a=10 # 10 is a value assigned in a

# %%
'A'=='a'
# Out:
# False

# %%
'A'==a # 'A'==10
# Out:
# False

# %%
print('the area of circle'==area_of_circle)
# Out:
# False

# %% [markdown]
# **Average Problem**

# %% [markdown]
# **Round**

# %%
a=10
b=20
c=30
avg=(a+b+c)/3 # 10
print(avg)
# Out:
# 20.0

# %%
a=10
b=21
c=30
avg=(a+b+c)/3 # 10
print(avg)
# Out:
# 20.333333333333332

# %%
round(10.6789) # 10.6 marks
# Out:
# 11

# %%
round(10.4321)
# Out:
# 10

# %%
round(10.6789,1)
# 1 indicates after decimal only one digit
# 6789====7000===7
# 10.7
# Out:
# 10.7

# %%
round(10.6789,2)
# 2 indicates after decimal only two digit
# 789====800===8
# 10.68
# Out:
# 10.68

# %%
a=10
b=21
c=30
avg=(a+b+c)/3 # 10+20+30/3 10+20+30
rounded_avg=round(avg,2)
print(f'the avg of {a},{b},{c} is:{rounded_avg}')
# Out:
# the avg of 10,21,30 is:20.33

# %% [markdown]
# - print()
# - type()
# - max()
# - min()
# - sum()
# - len()
# - round()

# %%
# () function call method
# whenever we miss the bracket
# it will indicate in two ways

# %% [markdown]
# - **Bound Method**
#
# - **Function**

# %%
import os
os.getcwd
# Bro recall we missed brackets
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rohit Prajapati\\Naresh IT\\Python Session_1'

# %%
name='python' # hard coded
# we fixed the value
# we need to ask the user enter any value
# different users can use the same code

# %% [markdown]
# -**input**

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x00000182B9703B60>>

# %%
input()
# Out:
#  python
# 'python'

# %%
input()
# Out:
#  30
# '30'

# %%
input()
# Out:
#  Hyderabad
# 'Hyderabad '

# %%
# Pending input
# your kernel is busy to execute another cell

# %%
input()
input()
input()
# Out:
#  Naresh it
#  22 years
#  Hyderabad
# 'Hyderabad'

# %%
name=input()
# Out:
#  naresh it

# %%
name
# Out:
# 'naresh it'

# %%
age=input()
# Out:
#  25

# %%
age
# Out:
# '25'

# %%
city=input()
# Out:
#  hyderabad

# %%
city
# Out:
# 'hyderabad'

# %%
name=input() # name ='naresh it'
age=input()  # age ='22' 
city=input() # city =Hyderabad 
print(f'my name is {name},my age is:{age}.I came from {city}')
# Out:
#  Naresh it
#  22
#  hyderabad
# my name is Naresh it ,my age is:22.I came from hyderabad

# %%
name=input('Enter your Name:') # name ='naresh it'
age=input('Enter your age:')  # age = '22'
city=input('Enter your city:') # city = 'Hyderabad '
print(f'my name is {name},my age is:{age}.I came from {city}')
# Out:
# Enter your Name: Naresh it
# Enter your age: 22
# Enter your city: Hyderabad
# my name is Naresh it,my age is:22.I came from Hyderabad

# %%
Name=input('Enter Your Name:')
Institute=input('Enter Your Institute Name:')
Course=input('Enter Your Course Name:')
Age=input('Enter Your Age:')
City=input('Enter Your City:')
print(f'My Name is : {Name}, I Studied in : {Institute} Institute, My Course is : {Course}, My Age is : {Age}, and I am From : {City},')
# Out:
# Enter Your Name: Rohit Prajapati
# Enter Your Institute Name: Naresh IT
# Enter Your Course Name: Data Science & AI.ML
# Enter Your Age: 25
# Enter Your City: Indore
# My Name is : Rohit Prajapati, I Studied in : Naresh IT Institute, My Course is : Data Science & AI.ML, My Age is : 25, and I am From : Indore,

# %%
name=input()
age=input()
city=input()
print(f'my name is {name},my age is {age},i came from city is {city}.format(name,age,city))
# Out:
#   Cell In[1], line 4
#     print(f'my name is {name},my age is {age},i came from city is {city}.format(name,age,city))
#           ^
# SyntaxError: unterminated f-string literal (detected at line 4)

# %% [markdown]
# **Syntax Error**
#
# - python expectation from you is : provide

# %%
name=input()
age=input()
city=input()
print(f'my name is {name},my age is {age},i came from city is {city}.')
# Out:
#  Rohit Prajapati
#  25
#  Indore
# my name is Rohit Prajapati,my age is 25,i came from city is Indore.

# %%
name=input('enter a name:')
name
# Out:
# enter a name: Naresh it
# 'Naresh it'

# %%
n1=input('enter a number:')
n1
# Out:
# enter a number: 100
# '100'

# %%
n1=input('enter a number:')
n1
# Out:
# enter a number: hundered
# 'hundered'

# %% [markdown]
# **Important Note**
#
# - When we provide a value from keyboard  By default python takes **String data type**
#
# - By default python takes **String data type**

# %%
n1=input('enter a number1:')
n2=input('enter a number2:')
n1+n2
# Out:
# enter a number1: 100
# enter a number2: 200
# '100200'

# %%
n1='100' #===== 100
n2='200'
n1+n2     #'100'+'200' = '100200'
# Out:
# '100200'

# %% [markdown]
# **Type Cast**
#
# - convert one data type to another data type
#
# - int,float,str,bool
#
# - if a user provide one data type we can able to convert it into other data types

# %% [markdown]
# **Now**
#
# **Coverting Interger to Other Data Types**

# %%
n1=100
# 100===> 100.0
float(n1)
# Out:
# 100.0

# %%
n1=100
# 100 ====string ==== '100'
str(n1)
# Out:
# '100'

# %%
n1=100
# 100 ==== bool === True
bool(100)
# Out:
# True

# %%
float(100),str(100),bool(100)
#100.0    , '100'     , True
# Out:
# (100.0, '100', True)

# %%
float(-100),str(-100),bool(-100)
#-100.0    , '-100'     , True
# Out:
# (-100.0, '-100', True)

# %% [markdown]
# **Remember For Bool**
#
# - True On something
#
# - Flase OFF Nothing

# %%
float(-100),str(-100),bool(-100)
#-100.0    , '-100'     , True   

#Remember For Bool

#True On something

#Flase OFF Nothing
# Out:
# (-100.0, '-100', True)

# %% [markdown]
# -**Now**
#
# -**Float TO Other**

# %%
int(10.5),str(10.5),bool(10.5)
# 10    ,  '10.5' , True
# Out:
# (10, '10.5', True)

# %%
int(-10.5),str(-10.5),bool(-10.5)
# 10    ,  '10.5' , True
# Out:
# (-10, '-10.5', True)

# %%
int(0.0),str(0.0),bool(0.0)
# 0    ,  '0.0' , False
# Out:
# (0, '0.0', False)

# %%
int(10.8),round(10.8)
# Out:
# (10, 11)

# %% [markdown]
# **String to other**

# %%
s1='apple'
s2=''
s3='100.5' # float in str

# %%
bool('apple')
# Out:
# True

# %%
int('100'),float('100'),bool('100')
# 100        #100.0     #true
# Out:
# (100, 100.0, True)

# %%
int('10.5') # 10 wrong
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float('10.5')
# Out:
# 10.5

# %%
# any  number people max they will represent float
# int ==== float
# 50000 === 50000.0
# 50000.25 === 50000

float('100'),float('100.5')
# Out:
# (100.0, 100.5)

# %%
int(100.5)
# Out:
# 100

# %%
int('100.5') # 10 wrong answer showing Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
float(100.5) # float can be used any time for any numerical value.
# Out:
# 100.5

# %%
bool('apple'),bool('100'),bool('10.5')
# Out:
# (True, True, True)

# %%
'apple' # 5 words
'app'   #3  words
'ap'    #2  words
'p'     #1  words
''      #0  words
# Out:
# ''

# %% [markdown]
# -int('100.5') # error
#
# -int('100') # 100
#
# -int('100.5') vs int(100.5)
#
# -int('0')     vs bool(0)

# %% [markdown]
# **Bool to other**

# %%
int(True)   #1
float(True) #1.0
str('True') #'True'
# Out:
# 'True'
