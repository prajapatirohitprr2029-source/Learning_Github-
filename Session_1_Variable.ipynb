# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Rohit Prajapati\\Naresh IT\\Python Session_1'

# %%
n1=100

# %%
n2=200

# %%
n1+n2
# Out:
# 300

# %% [markdown]
# **Name error**
#
# - you did not defined / initialized the variables

# %%
a=10  # a=10
b=20  # b=20
c=30  # c=30
b+d   # name error d is not defined
d=50
a+d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 b=20  # b=20
#       3 c=30  # c=30
# ----> 4 b+d   # name error d is not defined
#       5 d=50
#       6 a+d
#
# NameError: name 'd' is not defined

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber=400
NUMber
# Out:
# 400

# %%
number123=200
number123
# Out:
# 200

# %%
123number=300
123number
# Out:
#   Cell In[12], line 1
#     123number=300
#       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# - We cannot write number as prefix

# %%
num@ber=200
num@ber
# Out:
#   Cell In[3], line 1
#     num@ber=200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
$number=100
$number=100  # "special charachter's are not allowed".
# Out:
#   Cell In[2], line 1
#     $number=100
#     ^
# SyntaxError: invalid syntax

# %%
num_ber=200
num_ber
# Out:
# 200

# %%
areaofcircle=300          
area_of_circle=400     # underscore is treated as a God means its a special character but we can use it to simplify and to understand our code and line

# %%
num@ber=200   # F
$number=100   # F
num_ber=200  # W
areaofcircle=300   # F          
area_of_circle=400  # W
area of cirecle=500 # w
# Out:
#   Cell In[19], line 1
#     num@ber=200   # F
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# - num@ber=200   # F
# - $number=100   # F
# - num_ber=200  # W
# - areaofcircle=300   # W
# - area_of_circle=400  # W
# - area of circle=500 # F

# %%
if=500
# Out:
#   Cell In[8], line 1
#     if=500
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# - green is like a RED signal like traffic lights means wait something is wrong

# %%
sum=500
sum
# Out:
# 500

# %%
sum is from math family
max is from math family
min is from math family
len is from math family

# %%
l=[1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
sum(l)
# Out:
# 10

# %%
type(l)
# Out:
# list

# %%
l=[1,2,3,4]
sum(l)
# Out:
# 10

# %%
len(l)
# Out:
# 4

# %% [markdown]
# - Variable are case sensitive
#
# - Variables can be capital and samll letters
#
# - Variables does not include special characters
#
# - Number as prefix not allowed
#
# - Variables can only have Underscore (_)
#
# - Only underscore is also possible
#
# - Reserved or keywords can not be a variable
#
# - Inbuilt functions can not use as variable
