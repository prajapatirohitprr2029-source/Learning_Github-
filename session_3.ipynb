# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Rohit Prajapati\\Naresh IT\\Python Session_1'

# %% [markdown]
# - **STRING**

# %%
# Variable === black
# Keyword === green
# String === red
name = 'naresh it'
institute_name='naresh it'
coaching_center='naresh it'

#name
#institute_name
#coaching_center
name
# Out:
# 'naresh it'

# %%
print(name)
# Out:
# naresh it

# %%
print(coaching_center)
# Out:
# naresh it

# %%
name1='Naresh IT'
name2='nareshit@gmail.com'
name3='nareshit123'

# %%
name1
# Out:
# 'Naresh IT'

# %%
print(name1)
# Out:
# Naresh IT

# %%
greet1='hello'
greet2=' hello'
greet3='hello            '
greet4='        hello       '
len(greet1), len(greet2)
# Out:
# (5, 6)

# %%
print(greet1)
print(greet2)
print(greet3)
print(greet4)
# Out:
# hello
#  hello
# hello
#         hello

# %%
greet1,greet2,greet3,greet4
# Out:
# ('hello', ' hello', 'hello            ', '        hello       ')

# %% [markdown]
# - **Double quotes**

# %%
name1="Hyderabad"
# single and double quotes both are same
name1
# Out:
# 'Hyderabad'

# %%
s1="I joined in Ds and AI class"   #works 
s2= I joined in 'DS and Ai' class  #fail

# above statement is a information
# information in english
# red color ===> quotes
# single or double
# Out:
# 'I joined in Ds and AI class'

# %%
s1="I joined in Ds and AI class"    #works 
s2= "I joined in 'DS and Ai' class" #works

# %%
print(s1)
print(s2)
# Out:
# I joined in Ds and AI class
# I joined in 'DS and Ai' class

# %%
s2= 'I joined in "DS and Ai" class' #works
print(s2)
# Out:
# I joined in "DS and Ai" class

# %% [markdown]
# - **Triple Quotes**

# %% [markdown]
# - In jupyter notebook we have a **Markdown** option to write a inform
#
# - **Markdown** means we are conveying some information to the user
#
# - But in other playforms like **Vscode Pycharm** we dont have markdown option
#
# - We can convey the information using **Triple Quotes**
#
# - This is also called as **Doc String** (""" multiple lines or multilines """)
#
# - The code we provide we can provide single or Double Quotes
#
# - But conveying the information about the code is **Triple Quotes**
#
# - **Triple Quotes** are using in prompt engineering

# %% [markdown]
# **Booleen**
#
# - When we ask the question to machine
#
# - Machine always provie only teo answer
#
#   - True
#   - False
#
# - True means 1
#
# - False means 0
#
# - You can think in another way True mean On False means OFF

# %%
on=True
type(on)
# Out:
# bool

# %%
off=False
type(off)
# Out:
# bool

# %%
true # variable
'True' # string
True # bool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 true # variable
#       2 'True' # string
#       3 True
#
# NameError: name 'true' is not defined

# %%
can
