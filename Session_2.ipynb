# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Rohit Prajapati\\Naresh IT\\Python Session_1'

# %%
original_price=100
discount=10
discounted_price=original_price-(original_price*discount/100)
discounted_price=100-(100*10/100)
discounted_price
# Out:
# 90.0

# %%
salary=100000
tax_per=10
formula=salary*tax_per/100
formula=100000*10/100
formula
# Out:
# 10000.0

# %% [markdown]
# - int
#
# - float
#
# - complex
#
# - str
#
# - list
#
# - tuple
#
# - dict
#
# - set
#
# - frozenset
#
# - range
#
# - bytes
#
# - bytearray
#
# - memoryview
#
# - bool

# %% [markdown]
# **integer data type

# %%
number=100
type(number)
# Out:
# int

# %% [markdown]
# float data type

# %%
n1=10.5
type(n1)
# Out:
# float

# %%
print(1e1) # 1*10                 # preffix before e is multiplied by e means one zero 10 
print(1e2) # 1*100                # e2 means two zero that is 100  
print(2e3) # 2*1000               # e3 means three zero that is 1000
print(3e4) # 3*10000              # e4 means four zero that is 10000
print(4e5) # 4*100000             # e5 means five zero that is 100000
print(100e6) # 100*1000000        # e6 means six zero that is 1000000

print(2e15) # 2*1000000000000000   #e1000 means fifeteen zero that is 1000000000000000 it is last after 15 zero it print as ex:- 5e1000
print(5e1000) # or inf
# Out:
# 10.0
# 100.0
# 2000.0
# 30000.0
# 400000.0
# 100000000.0
# 2000000000000000.0
# inf

# %%
1e+1  # 1*10                  # we can also write (1e1) as 1e+1
1e-1  # 1*10                  # But 1e-1 is 1e-1
# Out:
# 0.1

# %%
2e+3  # 2*1000 
2e-3  # 2/1000
# Out:
# 0.002
